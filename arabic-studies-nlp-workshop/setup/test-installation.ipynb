# %% [markdown]
# # Test Your Installation
#
# **Purpose:** check whether the workshop environment is ready
# **Run after:** `setup/installation-guide.md`
#
# Run this notebook after following the installation guide. If all cells run, your workshop environment is ready.

# %% [markdown]
# ## Python and Packages
#
# The next cell checks whether Python can import the main packages used in the workshop.
#
# | Package | Used for |
# | --- | --- |
# | `pandas` | Tables and metadata |
# | `camel_tools` | Arabic NLP utilities |
# | `transformers` | Model demonstration |

# %%
import sys

print('Python version:', sys.version.split()[0])

try:
    import pandas as pd
    import camel_tools
    import transformers

    print('pandas version:', pd.__version__)
    print('CAMeL Tools version:', camel_tools.__version__)
    print('transformers version:', transformers.__version__)
    print('Package check: OK')
except Exception as error:
    print('Package check failed.')
    print('Reason:', error)

# %% [markdown]
# ## Sample Data
#
# The next cell checks whether Python can find and read the workshop sample text.

# %%
from pathlib import Path

sample = Path('../data/raw/openiti_sample.txt')
if not sample.exists():
    sample = Path('data/raw/openiti_sample.txt')

print('Sample file exists:', sample.exists())

if sample.exists():
    print('Sample text:')
    print(sample.read_text(encoding='utf-8'))
else:
    print('Check that JupyterLab was opened from the repository folder.')

# %% [markdown]
# ## What Success Looks Like
#
# | Check | Success marker |
# | --- | --- |
# | Python | A version number appears |
# | Packages | `Package check: OK` appears |
# | Data | Arabic sample text is printed |
#
# If you do not see these, open `troubleshooting.md` or ask the instructor for help.
