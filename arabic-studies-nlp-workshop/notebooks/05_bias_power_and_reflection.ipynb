# %% [markdown]
# # Bias, Power, and Reflection
#
# **Workshop stage:** 5 / interpretation
# **Main skill:** connect NLP outputs to scholarly judgment
# **Mode:** reading, writing, and discussion
#
# This final notebook turns from technique to interpretation. Arabic NLP is shaped by corpora, digitization histories, language ideologies, funding, platform choices, and model design.

# %% [markdown]
# ## Guided Humanities Questions
#
# | Question | Connect it to |
# | --- | --- |
# | Which texts and dialects appear in digital corpora? | Corpus construction |
# | Which communities, genres, scripts, or registers are less visible? | Representation |
# | How do OCR errors and transcription practices shape analysis? | Digitization |
# | How does power influence what is digitized and studied? | Institutions and infrastructure |
# | What does it mean to say a model is limited or biased? | Model interpretation |

# %% [markdown]
# ## Return to the Sample Text
#
# Read the sample again. This time, focus less on code and more on the assumptions behind turning this text into data.

# %%
from pathlib import Path

path = Path('../data/raw/openiti_sample.txt')
if not path.exists():
    path = Path('data/raw/openiti_sample.txt')

text = path.read_text(encoding='utf-8')
print(text)

# %% [markdown]
# ## Reflection Prompts
#
# Write a short response to one prompt:
#
# | Prompt | Focus |
# | --- | --- |
# | What context would you need before interpreting this sample? | Historical and literary evidence |
# | If this sample trained a model, what might it learn about Arabic? | Representation in data |
# | What might the model fail to learn? | Absence and bias |
# | How can computational tools support critical analysis? | Method and interpretation |

# %% [markdown]
# ## Pair Discussion
#
# In pairs or small groups, compare responses. Try to separate three things:
#
# | Layer | Example question |
# | --- | --- |
# | Code | What did the command do? |
# | Corpus | What does the sample make visible? |
# | Scholar | What still requires interpretation? |

# %% [markdown]
# ## Closing Note
#
# A responsible Arabic NLP workflow combines technical transparency with disciplinary judgment. Record preprocessing choices, inspect data provenance, question model authority, and connect computational results back to scholarly evidence.
